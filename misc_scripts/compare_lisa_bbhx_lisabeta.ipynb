# %% [markdown]
# # Compare LISABeta and BBHx LISA waveforms
#
# This notebook runs the same comparison and timing workflow as `compare_lisa_bbhx_lisabeta.py`, but from inside Jupyter.
#
# Run it in the cluster environment after bootstrapping modules, conda, and `PYTHONPATH` with `misc_scripts/lisa_cluster_bootstrap.sh` or the equivalent SLURM job setup.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd()
if not (repo_root / "misc_scripts").exists():
    repo_root = repo_root.parent

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from misc_scripts.compare_lisa_bbhx_lisabeta import (
    ComparisonConfig,
    environment_report,
    format_report,
    run_comparison,
)

environment_report()

# %%
config = ComparisonConfig(
    repeats=3,
    warmup=1,
    use_gpu=False,
    include_bbhx_direct=False,
)

report = run_comparison(config)
print(format_report(report))

# %%
# Optional: inspect the raw results dictionary.
report
